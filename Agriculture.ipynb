# %% [markdown]
# <a href="https://colab.research.google.com/github/zadevaibhav45/ml-odel/blob/master/Agriculture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df =pd.read_csv("apy-200719-175226.csv",na_values='=')

# %%
df.head()
# Out:
#                     State_Name District_Name  ...    Area Production
# 0  Andaman and Nicobar Islands      NICOBARS  ...  1254.0     2000.0
# 1  Andaman and Nicobar Islands      NICOBARS  ...     2.0        1.0
# 2  Andaman and Nicobar Islands      NICOBARS  ...   102.0      321.0
# 3  Andaman and Nicobar Islands      NICOBARS  ...   176.0      641.0
# 4  Andaman and Nicobar Islands      NICOBARS  ...   720.0      165.0
#
# [5 rows x 7 columns]

# %%
df.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df.Crop_Year.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2010, 1997, 1998, 1999,
#        2007, 2008, 2009, 2011, 2012, 2013, 2014, 2015])

# %%
df.dtypes
# Out:
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Crop              object
# Area             float64
# Production       float64
# dtype: object

# %%
df.Crop.unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Rapeseed &Mustard', 'Mesta',
#        'Cowpea(Lobia)', 'Lemon', 'Pome Granet', 'Sapota', 'Cabbage',
# ...

# %%
df.Season.unique()
# Out:
# array(['Kharif     ', 'Whole Year ', 'Autumn     ', 'Rabi       ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3727
# dtype: int64

# %%
df.shape
# Out:
# (246091, 7)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (242364, 7)

# %%
sns.kdeplot(df.Production)

# %%
sns.boxplot(df.Production)

# %%
sns.boxplot(df.Area)

# %%
df[df.State_Name =="Maharashtra"]['District_Name'].unique()
# Out:
# array(['AHMEDNAGAR', 'AKOLA', 'AMRAVATI', 'AURANGABAD', 'BEED',
#        'BHANDARA', 'BULDHANA', 'CHANDRAPUR', 'DHULE', 'GADCHIROLI',
#        'GONDIA', 'HINGOLI', 'JALGAON', 'JALNA', 'KOLHAPUR', 'LATUR',
#        'MUMBAI', 'NAGPUR', 'NANDED', 'NANDURBAR', 'NASHIK', 'OSMANABAD',
#        'PALGHAR', 'PARBHANI', 'PUNE', 'RAIGAD', 'RATNAGIRI', 'SANGLI',
#        'SATARA', 'SINDHUDURG', 'SOLAPUR', 'THANE', 'WARDHA', 'WASHIM',
#        'YAVATMAL'], dtype=object)

# %%
df.groupby(['State_Name','Crop','Crop_Year']).sum()
# Out:
#                                                      Area  Production
# State_Name                  Crop     Crop_Year
# Andaman and Nicobar Islands Arecanut 2000         4354.00     7200.00
#                                      2001         4354.00     7300.00
#                                      2002         4363.00     7350.00
#                                      2003         4379.00     6707.00
#                                      2004         4425.37     4781.05
# ...                                                   ...         ...
# West Bengal                 Wheat    2010       316808.00   874415.00
#                                      2011       315659.00   872895.00
#                                      2012       321572.00   895927.00
#                                      2013       331481.00   927837.00
#                                      2014       334640.00   939254.00
#
# [12896 rows x 2 columns]

# %%
df[df.State_Name == 'Maharashtra']['Crop'].unique()
# Out:
# array(['Maize', 'Arhar/Tur', 'Bajra', 'Gram', 'Jowar',
#        'Moong(Green Gram)', 'Pulses total', 'Ragi', 'Rice', 'Sugarcane',
#        'Total foodgrain', 'Urad', 'Other  Rabi pulses', 'Wheat',
#        'Cotton(lint)', 'Castor seed', 'Groundnut', 'Niger seed',
#        'Other Cereals & Millets', 'Other Kharif pulses', 'Sesamum',
#        'Soyabean', 'Sunflower', 'Linseed', 'Safflower', 'Small millets',
#        'Rapeseed &Mustard', 'other oilseeds', 'Banana', 'Grapes', 'Mango',
#        'Onion', 'Tomato', 'Tobacco'], dtype=object)

# %%
df.groupby(['State_Name','Crop_Year']).sum()
# Out:
#                                              Area   Production
# State_Name                  Crop_Year
# Andaman and Nicobar Islands 2000         44518.00  89060914.00
#                             2001         41163.00  89718700.00
#                             2002         45231.40  94387137.67
#                             2003         44799.40  95296454.67
#                             2004         45308.77  87186497.63
# ...                                           ...          ...
# West Bengal                 2010       7246875.00  38308645.00
#                             2011       7755360.00  36777774.00
#                             2012       7850936.00  38918275.00
#                             2013       7999815.00  37901281.00
#                             2014       8058390.00  43584403.00
#
# [519 rows x 2 columns]

# %%
df1 = df.groupby(['State_Name','Crop','Crop_Year']).sum()

# %%
df1.reset_index(inplace=True)

# %%
df1.head()
# Out:
#                     State_Name      Crop  Crop_Year     Area  Production
# 0  Andaman and Nicobar Islands  Arecanut       2000  4354.00     7200.00
# 1  Andaman and Nicobar Islands  Arecanut       2001  4354.00     7300.00
# 2  Andaman and Nicobar Islands  Arecanut       2002  4363.00     7350.00
# 3  Andaman and Nicobar Islands  Arecanut       2003  4379.00     6707.00
# 4  Andaman and Nicobar Islands  Arecanut       2004  4425.37     4781.05

# %%
df1[['State_Name', 'Crop_Year']].groupby('State_Name').count()
# Out:
#                              Crop_Year
# State_Name
# Andaman and Nicobar Islands         93
# Andhra Pradesh                     716
# Arunachal Pradesh                  191
# Assam                              548
# Bihar                              602
# Chandigarh                          89
# Chhattisgarh                       617
# Dadra and Nagar Haveli             235
# Goa                                 93
# Gujarat                            440
# Haryana                            413
# Himachal Pradesh                   297
# Jammu and Kashmir                  228
# Jharkhand                           73
# Karnataka                          747
# Kerala                             377
# Madhya Pradesh                     604
# Maharashtra                        400
# Manipur                            202
# Meghalaya                          465
# Mizoram                            168
# Nagaland                           435
# Odisha                             375
# ...

# %%
sns.lineplot(x = "Crop_Year", y = "Area", data=df[df.State_Name == "Maharashtra"])

# %%
sns.lineplot(x = "Crop_Year", y = "Production", data=df, hue="State_Name");

# %%
# !pip install plotly_express

# %%
import plotly_express as px

# %%
px.scatter(df1,x= 'Area', y='Production', animation_frame="Crop_Year",animation_group="State_Name", color="State_Name")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b51962a8-3092-4f98-9a15-e0c4af158191" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b51962a8-3092-4f98-9a15-e0c4af158191")) {
#                     Plotly.newPlot(
#                         'b51962a8-3092-4f98-9a15-e0c4af158191',
# ...

# %%
df1.sort_values('Crop_Year',inplace=True)

# %%
df1[(df1.State_Name == "Maharashtra") & (df1.Crop_Year == 2000)]
# Out:
#        State_Name                 Crop  Crop_Year       Area  Production
# 6558  Maharashtra   Other  Rabi pulses       2000   101700.0     37700.0
# 6571  Maharashtra  Other Kharif pulses       2000   394900.0    139100.0
# 6540  Maharashtra           Niger seed       2000    60700.0     13340.0
# 6523  Maharashtra    Moong(Green Gram)       2000   714300.0    243900.0
# 6584  Maharashtra                 Ragi       2000   154900.0    128600.0
# 6651  Maharashtra              Sesamum       2000   136900.0     30210.0
# 6667  Maharashtra        Small millets       2000   181300.0    112700.0
# 6601  Maharashtra    Rapeseed &Mustard       2000     8200.0      1900.0
# 6617  Maharashtra                 Rice       2000  1511500.0   1929700.0
# 6634  Maharashtra            Safflower       2000   296000.0    121900.0
# 6384  Maharashtra                Bajra       2000  1800000.0   1087200.0
# 6453  Maharashtra            Groundnut       2000   490100.0    469610.0
# ...

# %%
df[(df.State_Name == "Maharashtra") & (df.Crop_Year == 2000)].sort_values('Production')
# Out:
#        State_Name                 Crop  Crop_Year       Area  Production
# 6601  Maharashtra    Rapeseed &Mustard       2000     8200.0      1900.0
# 6402  Maharashtra          Castor seed       2000    18100.0      4350.0
# 6540  Maharashtra           Niger seed       2000    60700.0     13340.0
# 6487  Maharashtra              Linseed       2000    69900.0     16300.0
# 6651  Maharashtra              Sesamum       2000   136900.0     30210.0
# 6558  Maharashtra   Other  Rabi pulses       2000   101700.0     37700.0
# 6667  Maharashtra        Small millets       2000   181300.0    112700.0
# 6634  Maharashtra            Safflower       2000   296000.0    121900.0
# 6584  Maharashtra                 Ragi       2000   154900.0    128600.0
# 6571  Maharashtra  Other Kharif pulses       2000   394900.0    139100.0
# 6707  Maharashtra            Sunflower       2000   337200.0    175300.0
# 6729  Maharashtra                 Urad       2000   574000.0    205100.0
# ...
